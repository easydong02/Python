# %%
from selenium import webdriver #웹 접근 
from bs4 import BeautifulSoup #분석을 용이하게 html
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
from selenium import webdriver
import time

# %%
https://www.mcdonalds.co.kr/kor/store/list.do
#container > div.content > div.contArea > div > div > button > span

# %%
driver = webdriver.Chrome('star.exe')
driver.get("https://www.mcdonalds.co.kr/kor/store/list.do")
# Out:
# <ipython-input-15-7ae619cfb631>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('star.exe')

# %%
area_btn= '#container > div.content > div.contArea > div > div > button > span'
driver.find_element_by_css_selector(area_btn).click()
# Out:
# <ipython-input-16-ec1210fa86a9>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(area_btn).click()

# %%
html = driver.page_source
soup = BeautifulSoup(html,"html.parser")

# %%
mc_soup_list =[]
mc_soup_list +=soup.select("dd.road")
mc_soup_list
# Out:
# [<dd class="road">서울 구로구 디지털로31길 12 태평양물산 1층 맥도날드</dd>,
#  <dd class="road">서울 구로구 새말로 97 (구로동)</dd>,
#  <dd class="road">서울 구로구 경인로 662 디큐브시티 B2</dd>,
#  <dd class="road">서울 금천구 벚꽃로 298 대륭포스트타워 6차</dd>,
#  <dd class="road">서울 영등포구 여의대방로 145 세인트빌딩</dd>]

# %%
mc_soup_list +=soup.select("dd.road")
mc_soup_list
# Out:
# [<dd class="road">서울 구로구 디지털로31길 12 태평양물산 1층 맥도날드</dd>,
#  <dd class="road">서울 구로구 새말로 97 (구로동)</dd>,
#  <dd class="road">서울 구로구 경인로 662 디큐브시티 B2</dd>,
#  <dd class="road">서울 금천구 벚꽃로 298 대륭포스트타워 6차</dd>,
#  <dd class="road">서울 영등포구 여의대방로 145 세인트빌딩</dd>,
#  <dd class="road">서울 금천구 디지털로 185 마리오아울렛1</dd>,
#  <dd class="road">서울 금천구 가산디지털1로 165 (가산동)</dd>,
#  <dd class="road">서울 영등포구 경인로 855</dd>,
#  <dd class="road">서울 구로구 경인로 393</dd>,
#  <dd class="road">서울 관악구 신림로 310</dd>,
#  <dd class="road">경기 광명시 철망산로 87</dd>,
#  <dd class="road">경기 광명시 오리로856번길 17 (철산동) </dd>,
#  <dd class="road">서울 양천구 목동동로 71 (신정동) </dd>,
#  <dd class="road">서울 영등포구 선유로 195</dd>,
#  <dd class="road">서울 영등포구 국제금융로 10 L3층</dd>,
#  <dd class="road">경기 광명시 광명로 895-1 (광명동)</dd>,
#  <dd class="road">서울 동작구 노량진로 158</dd>,
#  <dd class="road">서울 양천구 목동로 221</dd>,
#  <dd class="road">서울 양천구 목동서로 45 (목동) </dd>,
#  <dd class="road">서울 금천구 시흥대로 184</dd>,
#  <dd class="road">서울 동작구 사당로 22 창주빌딩 1층</dd>,
# ...

# %%
html = driver.page_source
soup = BeautifulSoup(html,"html.parser")

mc_soup_list +=soup.select("dd.road")
mc_soup_list
# Out:
# [<dd class="road">서울 구로구 디지털로31길 12 태평양물산 1층 맥도날드</dd>,
#  <dd class="road">서울 구로구 새말로 97 (구로동)</dd>,
#  <dd class="road">서울 구로구 경인로 662 디큐브시티 B2</dd>,
#  <dd class="road">서울 금천구 벚꽃로 298 대륭포스트타워 6차</dd>,
#  <dd class="road">서울 영등포구 여의대방로 145 세인트빌딩</dd>,
#  <dd class="road">서울 금천구 디지털로 185 마리오아울렛1</dd>,
#  <dd class="road">서울 금천구 가산디지털1로 165 (가산동)</dd>,
#  <dd class="road">서울 영등포구 경인로 855</dd>,
#  <dd class="road">서울 구로구 경인로 393</dd>,
#  <dd class="road">서울 관악구 신림로 310</dd>,
#  <dd class="road">경기 광명시 철망산로 87</dd>,
#  <dd class="road">경기 광명시 오리로856번길 17 (철산동) </dd>,
#  <dd class="road">서울 양천구 목동동로 71 (신정동) </dd>,
#  <dd class="road">서울 영등포구 선유로 195</dd>,
#  <dd class="road">서울 영등포구 국제금융로 10 L3층</dd>,
#  <dd class="road">경기 광명시 광명로 895-1 (광명동)</dd>,
#  <dd class="road">서울 동작구 노량진로 158</dd>,
#  <dd class="road">서울 양천구 목동로 221</dd>,
#  <dd class="road">서울 양천구 목동서로 45 (목동) </dd>,
#  <dd class="road">서울 금천구 시흥대로 184</dd>,
#  <dd class="road">서울 동작구 사당로 22 창주빌딩 1층</dd>,
# ...

# %%
i=3
area_btn= '#container > div.content > div.contArea > div > div > div.mcStore > div > span > a:nth-child('+i+')'
#driver.find_element_by_css_selector(area_btn).click()
#container > div.content > div.contArea > div > div > div.mcStore > div > span > a:nth-child(2)

# %%
i=3
area_btn1= '#container > div.content > div.contArea > div > div > div.mcStore > div > span > a:nth-child('+str(i)+')'
driver.find_element_by_css_selector(area_btn1).click()
# Out:
# <ipython-input-38-2235b751bb13>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(area_btn1).click()

# %%
mc_soup_list2 =[]

html2 = driver.page_source
soup2 = BeautifulSoup(html2,"html.parser")

mc_soup_list2 +=soup2.select("dd.road")
mc_soup_list2
# Out:
# [<dd class="road">서울 구로구 디지털로31길 12 태평양물산 1층 맥도날드</dd>,
#  <dd class="road">서울 구로구 새말로 97 (구로동)</dd>,
#  <dd class="road">서울 구로구 경인로 662 디큐브시티 B2</dd>,
#  <dd class="road">서울 금천구 벚꽃로 298 대륭포스트타워 6차</dd>,
#  <dd class="road">서울 영등포구 여의대방로 145 세인트빌딩</dd>]

# %%
for i in range(2,11):
    area_btn2= '#container > div.content > div.contArea > div > div > div.mcStore > div > span > a:nth-child('+str(i)+')'
    driver.find_element_by_css_selector(area_btn2).click()
    time.sleep(2)
    html2 = driver.page_source
    soup2 = BeautifulSoup(html2,"html.parser")

    mc_soup_list2 +=soup2.select("dd.road")
# Out:
# <ipython-input-52-62c693a98d82>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(area_btn2).click()

# %%
html2 = driver.page_source
soup2 = BeautifulSoup(html2,"html.parser")

mc_soup_list2 +=soup2.select("dd.road")
mc_soup_list2
# Out:
# [<dd class="road">서울 구로구 디지털로31길 12 태평양물산 1층 맥도날드</dd>,
#  <dd class="road">서울 구로구 새말로 97 (구로동)</dd>,
#  <dd class="road">서울 구로구 경인로 662 디큐브시티 B2</dd>,
#  <dd class="road">서울 금천구 벚꽃로 298 대륭포스트타워 6차</dd>,
#  <dd class="road">서울 영등포구 여의대방로 145 세인트빌딩</dd>,
#  <dd class="road">서울 금천구 디지털로 185 마리오아울렛1</dd>,
#  <dd class="road">서울 금천구 가산디지털1로 165 (가산동)</dd>,
#  <dd class="road">서울 영등포구 경인로 855</dd>,
#  <dd class="road">서울 구로구 경인로 393</dd>,
#  <dd class="road">서울 관악구 신림로 310</dd>,
#  <dd class="road">경기 광명시 철망산로 87</dd>,
#  <dd class="road">경기 광명시 오리로856번길 17 (철산동) </dd>,
#  <dd class="road">서울 양천구 목동동로 71 (신정동) </dd>,
#  <dd class="road">서울 영등포구 선유로 195</dd>,
#  <dd class="road">서울 영등포구 국제금융로 10 L3층</dd>,
#  <dd class="road">경기 광명시 광명로 895-1 (광명동)</dd>,
#  <dd class="road">서울 동작구 노량진로 158</dd>,
#  <dd class="road">서울 양천구 목동로 221</dd>,
#  <dd class="road">서울 양천구 목동서로 45 (목동) </dd>,
#  <dd class="road">서울 금천구 시흥대로 184</dd>,
#  <dd class="road">서울 동작구 사당로 22 창주빌딩 1층</dd>,
# ...

# %%
mc_soup_list2
# Out:
# [<dd class="road">서울 구로구 디지털로31길 12 태평양물산 1층 맥도날드</dd>,
#  <dd class="road">서울 구로구 새말로 97 (구로동)</dd>,
#  <dd class="road">서울 구로구 경인로 662 디큐브시티 B2</dd>,
#  <dd class="road">서울 금천구 벚꽃로 298 대륭포스트타워 6차</dd>,
#  <dd class="road">서울 영등포구 여의대방로 145 세인트빌딩</dd>,
#  <dd class="road">서울 금천구 디지털로 185 마리오아울렛1</dd>,
#  <dd class="road">서울 금천구 가산디지털1로 165 (가산동)</dd>,
#  <dd class="road">서울 영등포구 경인로 855</dd>,
#  <dd class="road">서울 구로구 경인로 393</dd>,
#  <dd class="road">서울 관악구 신림로 310</dd>,
#  <dd class="road">경기 광명시 철망산로 87</dd>,
#  <dd class="road">경기 광명시 오리로856번길 17 (철산동) </dd>,
#  <dd class="road">서울 양천구 목동동로 71 (신정동) </dd>,
#  <dd class="road">서울 영등포구 선유로 195</dd>,
#  <dd class="road">서울 영등포구 국제금융로 10 L3층</dd>,
#  <dd class="road">경기 광명시 광명로 895-1 (광명동)</dd>,
#  <dd class="road">서울 동작구 노량진로 158</dd>,
#  <dd class="road">서울 양천구 목동로 221</dd>,
#  <dd class="road">서울 양천구 목동서로 45 (목동) </dd>,
#  <dd class="road">서울 금천구 시흥대로 184</dd>,
#  <dd class="road">서울 동작구 사당로 22 창주빌딩 1층</dd>,
# ...

# %%
#container > div.content > div.contArea > div > div > div.mcStore > div > span > a:nth-child(2)

# %%
mc_soup_list2.insert(0,'시군구명')
mc_soup_list2
# Out:
# ['시군구명',
#  <dd class="road">서울 구로구 디지털로31길 12 태평양물산 1층 맥도날드</dd>,
#  <dd class="road">서울 구로구 새말로 97 (구로동)</dd>,
#  <dd class="road">서울 구로구 경인로 662 디큐브시티 B2</dd>,
#  <dd class="road">서울 금천구 벚꽃로 298 대륭포스트타워 6차</dd>,
#  <dd class="road">서울 영등포구 여의대방로 145 세인트빌딩</dd>,
#  <dd class="road">서울 금천구 디지털로 185 마리오아울렛1</dd>,
#  <dd class="road">서울 금천구 가산디지털1로 165 (가산동)</dd>,
#  <dd class="road">서울 영등포구 경인로 855</dd>,
#  <dd class="road">서울 구로구 경인로 393</dd>,
#  <dd class="road">서울 관악구 신림로 310</dd>,
#  <dd class="road">경기 광명시 철망산로 87</dd>,
#  <dd class="road">경기 광명시 오리로856번길 17 (철산동) </dd>,
#  <dd class="road">서울 양천구 목동동로 71 (신정동) </dd>,
#  <dd class="road">서울 영등포구 선유로 195</dd>,
#  <dd class="road">서울 영등포구 국제금융로 10 L3층</dd>,
#  <dd class="road">경기 광명시 광명로 895-1 (광명동)</dd>,
#  <dd class="road">서울 동작구 노량진로 158</dd>,
#  <dd class="road">서울 양천구 목동로 221</dd>,
#  <dd class="road">서울 양천구 목동서로 45 (목동) </dd>,
#  <dd class="road">서울 금천구 시흥대로 184</dd>,
#  <dd class="road">서울 동작구 사당로 22 창주빌딩 1층</dd>,
# ...

# %%
del mc_soup_list2[0]
mc_soup_list2_df=pd.DataFrame(mc_soup_list2,columns=['주소']) 

mc_soup_list2_df
# Out:
#                                   주소
# 0    서울 구로구 디지털로31길 12 태평양물산 1층 맥도날드
# 1                서울 구로구 새말로 97 (구로동)
# 2            서울 구로구 경인로 662 디큐브시티 B2
# 3          서울 금천구 벚꽃로 298 대륭포스트타워 6차
# 4            서울 영등포구 여의대방로 145 세인트빌딩
# ..                               ...
# 160                  서울 강동구 상일로6길 39
# 161            인천 연수구 하모니로 128 (송도동)
# 162         경기 성남시 분당구 성남대로 45 (구미동)
# 163               경기 용인시 수지구 신수로 677
# 164       경기 용인시 수지구 풍덕천로 119 (풍덕천동)
#
# [165 rows x 1 columns]

# %%
mc_soup_list2_df=mc_soup_list2_df[mc_soup_list2_df['주소'].split()[0]=='서울']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-c8a9ad771454> in <module>
# ----> 1 mc_soup_list2_df=mc_soup_list2_df[mc_soup_list2_df['주소'].split()[0]=='서울']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
sgg_names=[]
for idx in mc_soup_list2_df['주소']:
    if idx.split()[0]=='서울':
        sgg_names.append(idx.split()[1])

sgg_names
# Out:
# ['구로구',
#  '구로구',
#  '구로구',
#  '금천구',
#  '영등포구',
#  '금천구',
#  '금천구',
#  '영등포구',
#  '구로구',
#  '관악구',
#  '양천구',
#  '영등포구',
#  '영등포구',
#  '동작구',
#  '양천구',
#  '양천구',
#  '금천구',
#  '동작구',
#  '동작구',
#  '양천구',
#  '강서구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '양천구',
#  '동작구',
#  '강서구',
#  '서대문구',
#  '서초구',
#  '용산구',
#  '용산구',
#  '마포구',
#  '서초구',
#  '서초구',
#  '중구',
#  '강서구',
#  '중구',
#  '중구',
#  '서대문구',
#  '강남구',
#  '강남구',
#  '종로구',
#  '은평구',
#  '서초구',
#  '강남구',
#  '강남구',
#  '서초구',
#  '서초구',
#  '은평구',
#  '강남구',
#  '강남구',
#  '종로구',
#  '강남구',
#  '강남구',
#  '종로구',
#  '종로구',
#  '은평구',
#  '강남구',
#  '성북구',
#  '강남구',
#  '성동구',
#  '강남구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '송파구',
#  '성북구',
#  '광진구',
#  '동대문구',
#  '광진구',
#  '강북구',
#  '동대문구',
#  '송파구',
#  '동대문구',
#  '강북구',
#  '송파구',
#  '중랑구',
#  '강북구',
#  '중랑구',
#  '송파구',
#  '중랑구',
#  '도봉구',
#  '강동구',
#  '노원구',
#  '노원구',
#  '송파구',
#  '노원구',
#  '강동구',
#  '도봉구',
#  '노원구',
#  '노원구',
#  '강동구']

# %%
sgg_names= pd.DataFrame(sgg_names)

sgg_names
# Out:
#        0
# 0    구로구
# 1    구로구
# 2    구로구
# 3    금천구
# 4   영등포구
# ..   ...
# 87   강동구
# 88   도봉구
# 89   노원구
# 90   노원구
# 91   강동구
#
# [92 rows x 1 columns]

# %%
mc_sgg_count = sgg_names.pivot_table(index=0,values=0,aggfunc='count').rename(columns={"주소":"쇼핑몰 매장수"})

mc_sgg_count
# Out:
# Empty DataFrame
# Columns: []
# Index: [강남구, 강동구, 강북구, 강서구, 관악구, 광진구, 구로구, 금천구, 노원구, 도봉구, 동대문구, 동작구, 마포구, 서대문구, 서초구, 성동구, 성북구, 송파구, 양천구, 영등포구, 용산구, 은평구, 종로구, 중구, 중랑구]

# %%
count=0

for i in sgg_names:
    if i =='중랑구':
        count +=1

count
# Out:
# 3
